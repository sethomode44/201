# %% [markdown]
# <a href="https://colab.research.google.com/github/sethomode44/201/blob/main/Ex09-Alpha%20and%20Beta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Investments: Theory and Data Analysis**, Bates, Boyer, and Fletcher

# %% [markdown]
# # Example Chapter 9: Estimating Alpha and Beta
# In this example, we estimate the alphas and betas for decile portfolios posted in the Ken French Data Library.

# %% [markdown]
# ### Imports and Setup

# %%
# Import packages
# %pip install -q simple-finance
import simple_finance as sf
import requests
import pandas as pd
import numpy as np

# Establish display options when printing DataFrames
pd.set_option('display.max_columns', None)   # Show all columns without truncation
pd.set_option('display.width', 1000)   # Set the display width so output stays on one line
pd.set_option("display.max_rows", 20) # Force truncation if DataFrame has more than 20 rows

# %% [markdown]
# ### Load in Data Using the Python Function
# See Ex07-Ken_French.ipynb for a complete describption of the function in the course GiHub repo.

# %%
# Get returns on short-term reveral deciles
df=sf.get_ff_strategies('momentum', details=True)
# Out:
# ----------------
# Momentum Strategy
# ----------------
# Basic Strategy: stocks are sorted into deciles based on their prior 12-month returns, excluding the most recent month.
#
# Construction: The portfolios are constructed monthly using NYSE prior (2-12) return decile breakpoints.
#
# Stocks: The portfolios constructed each month include NYSE, AMEX, and NASDAQ stocks with prior return data.
# To be included in a portfolio for month t (formed at the end of month t-1), a stock must have a price for the
# end of month t-13 and a good return for t-2. In addition, any missing returns from t-12 to t-3 must be -99.0,
# CRSP's code for a missing price. Each included stock also must have ME for the end of month t-1.
#
# Min Date: 1927-01, Max Date: 2025-12

# %%
print(df)
# Out:
#           Dec 1   Dec 2   Dec 3   Dec 4   Dec 5   Dec 6   Dec 7   Dec 8   Dec 9  Dec 10  mkt-rf     smb     hml      rf
# date
# 1927-01 -0.0332 -0.0454  0.0267 -0.0029 -0.0041  0.0093  0.0030  0.0071 -0.0014 -0.0024 -0.0005 -0.0032  0.0458  0.0025
# 1927-02  0.0739  0.0601  0.0703  0.0746  0.0434  0.0398  0.0299  0.0320  0.0414  0.0704  0.0417  0.0007  0.0272  0.0026
# 1927-03 -0.0323 -0.0305 -0.0384 -0.0480 -0.0046 -0.0235  0.0196  0.0049  0.0035  0.0613  0.0014 -0.0177 -0.0238  0.0030
# 1927-04  0.0128 -0.0301 -0.0244  0.0043  0.0119 -0.0016  0.0203 -0.0074  0.0181  0.0549  0.0047  0.0039  0.0065  0.0025
# 1927-05  0.0271  0.0454  0.0597  0.0314  0.0614  0.0593  0.0522  0.0632  0.0819  0.0592  0.0545  0.0155  0.0480  0.0030
# ...         ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2025-08  0.1157  0.0546  0.0523  0.0827  0.0249  0.0725  0.0323 -0.0118  0.0123 -0.0126  0.0184  0.0387  0.0442  0.0038
# 2025-09  0.0313 -0.0233 -0.0010  0.0497 -0.0089  0.0027  0.0119  0.0470  0.0358  0.0782  0.0339 -0.0185 -0.0105  0.0033
# 2025-10  0.0028 -0.0025  0.0430  0.0077  0.0392 -0.0233  0.0050  0.0344  0.0293  0.0468  0.0196 -0.0055 -0.0309  0.0037
# 2025-11 -0.0062  0.0307  0.0276  0.0725  0.0156  0.0240  0.0031  0.0019 -0.0140 -0.0363 -0.0013  0.0038  0.0376  0.0030
# 2025-12  0.0260  0.0224  0.0222  0.0047  0.0017  0.0105 -0.0073 -0.0049 -0.0039 -0.0026 -0.0036 -0.0106  0.0242  0.0034
#
# [1188 rows x 14 columns]

# %% [markdown]
# ### Estaimte Alpha and Beta

# %%
# Estimate alpha and beta of decile 1 relative to market portfolio.
df['dec1_excess'] = df['Dec 1'] - df['rf']

results = sf.run_ols(df['mkt-rf'], df['dec1_excess'])

print(results)
# Out:
#             coef  ci_lower  ci_upper
# const  -0.009678 -0.012665 -0.006691
# mkt-rf  1.559469  1.503746  1.615192

# %%
# Estimate alpha and beta of decile 10 relative to market portfolio.
df['dec10_excess'] = df['Dec 10'] - df['rf']

results = sf.run_ols(df['mkt-rf'], df['dec10_excess'])

print(results)
# Out:
#             coef  ci_lower  ci_upper
# const   0.005273  0.003286  0.007260
# mkt-rf  1.018253  0.981194  1.055313
